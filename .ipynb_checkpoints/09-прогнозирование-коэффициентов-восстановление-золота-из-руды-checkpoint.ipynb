# %% [markdown]
# # Прогнозирование коэффициентов восстановление золота из руды

# %% [markdown]
# <h1>Оглавление проекта<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта-" data-toc-modified-id="Описание-проекта--1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта <a name="1"></a></a></span><ul class="toc-item"><li><span><a href="#Технологический-процесс" data-toc-modified-id="Технологический-процесс-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Технологический процесс</a></span><ul class="toc-item"><li><span><a href="#Флотация" data-toc-modified-id="Флотация-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Флотация</a></span></li><li><span><a href="#Очистка" data-toc-modified-id="Очистка-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Очистка</a></span></li></ul></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Параметры-этапов" data-toc-modified-id="Параметры-этапов-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Параметры этапов</a></span></li><li><span><a href="#Наименование-признаков" data-toc-modified-id="Наименование-признаков-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Наименование признаков</a></span></li><li><span><a href="#Расчёт-эффективности" data-toc-modified-id="Расчёт-эффективности-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Расчёт эффективности</a></span></li><li><span><a href="#Метрика-качества" data-toc-modified-id="Метрика-качества-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Метрика качества</a></span></li></ul></li><li><span><a href="#Подготовка-данных-" data-toc-modified-id="Подготовка-данных--2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных <a name="2"></a></a></span></li><li><span><a href="#Исследовательский-анализ-данных-" data-toc-modified-id="Исследовательский-анализ-данных--3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных <a name="3"></a></a></span></li><li><span><a href="#Обучение-и-проверка-модели-" data-toc-modified-id="Обучение-и-проверка-модели--4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Обучение и проверка модели <a name="4"></a></a></span></li><li><span><a href="#Общий-вывод-" data-toc-modified-id="Общий-вывод--5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод <a name="5"></a></a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта <a name="1"></a>
#
# Подготовим прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель будет предсказать коэффициент восстановления золота из золотосодержащей руды. В нашем распоряжении данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# ### Технологический процесс
# Когда добытая руда проходит первичную обработку, получается дроблёная смесь. Её отправляют на флотацию (обогащение) и двухэтапную очистку.
#
# Опишем каждую стадию:
# #### Флотация
#
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
#
# #### Очистка
#
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.
#
#
#
# ### Описание данных
#
# * Rougher feed — исходное сырье
# * Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#      Xanthate — ксантогенат (промотер, или активатор флотации);
#      Sulphate — сульфат (на данном производстве сульфид натрия);
#      Depressant — депрессант (силикат натрия).
# * Rougher process (англ. «грубый процесс») — флотация
# * Rougher tails — отвальные хвосты
# * Float banks — флотационная установка
# * Cleaner process — очистка
# * Rougher Au — черновой концентрат золота
# * Final Au — финальный концентрат золота
#
# ### Параметры этапов
#
# * air amount — объём воздуха
# * fluid levels — уровень жидкости
# * feed size — размер гранул сырья
# * feed rate — скорость подачи
#
# ### Наименование признаков
#
# Наименование признаков должно быть такое:
# [этап].[тип_параметра].[название_параметра]
#
# Пример: *rougher.input.feed_ag*
#
# Возможные значения для блока [этап]:
#
# * rougher — флотация
# * primary_cleaner — первичная очистка
# * secondary_cleaner — вторичная очистка
# * final — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
#
# * input — параметры сырья
# * output — параметры продукта
# * state — параметры, характеризующие текущее состояние этапа
# * calculation — расчётные характеристики
#
# ### Расчёт эффективности
#
# Эффективность обогащения рассчитывается по формуле
#
# $$
# \text{Recovery} = \frac{C \cdot (F - T) \cdot 100}{F \cdot (C - T)}
# $$
#
# где:
#
# * C — доля золота в концентрате после флотации/очистки;
# * F — доля золота в сырье/концентрате до флотации/очистки;
# * T — доля золота в отвальных хвостах после флотации/очистки.
#
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.
#
# ### Метрика качества
#
# Для решения задачи будем использовать метрику SMAPE (Symmetric Mean Absolute Percentage Error, симметричное среднее абсолютное процентное отклонение)
#
# $$
# \text{SMAPE} = \frac{1}{N} \sum^{N}_{i=1}\,\frac{|y_i - \hat y_i|}{(|y_i| + |\hat y_i|)\,/\,2}\times 100\%
# $$
#
# $y_i$ - значение целевого признака для объекта с порядковым номером i в выборке, на которой измеряется качество.
#
# $\hat y_i$ - значение предсказания для объекта с порядковым номером i, например, в тестовой выборке.
#
# N - количество объектов в выборке.
#
# Мы будем прогнозировать сразу две величины:
#
# 1. Эффективность обогащения чернового концентрата rougher.output.recovery;
# 2. Эффективность обогащения финального концентрата final.output.recovery.
#
# Итоговая метрика складывается из двух величин:
#
# $\text{SMAPE}_{total} = 25\% \cdot \text{SMAPE}_{rougher} + 75\% \cdot \text{SMAPE}_{final}$

# %% [markdown]
# ## Подготовка данных <a name="2"></a>

# %% [markdown]
# Импортируем необходимые библиотеки, классы и функции.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from scipy import stats as st
from numpy.random import RandomState
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.scorer import make_scorer
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Загрузим данные. Данные находятся в трёх файлах:
# * gold_recovery_train.csv — обучающая выборка;
# * gold_recovery_test.csv — тестовая выборка;
# * gold_recovery_full.csv — исходные данные.
#
# Учтем, что в столбце date хранятся дата и время замера, все поля различны и по ним можно будет связывать данные в обучающем, тестовом и полном наборе.

# %%
train = pd.read_csv('/datasets/gold_recovery_train.csv', index_col='date')
train.head()
# Out:
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
# 2016-01-15 01:00:00                     6.029369                     9.968944
# 2016-01-15 02:00:00                     6.055926                    10.213995
# 2016-01-15 03:00:00                     6.047977                     9.977019
# 2016-01-15 04:00:00                     6.148599                    10.142511
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
# 2016-01-15 01:00:00                      5.257781
# 2016-01-15 02:00:00                      5.383759
# 2016-01-15 03:00:00                      4.858634
# 2016-01-15 04:00:00                      4.939416
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2016-01-15 00:00:00                    42.192020              70.541216
# ...

# %%
test = pd.read_csv('/datasets/gold_recovery_test.csv', index_col='date')
test.head()
# Out:
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
# 2016-09-01 01:59:59                     215.392455
# 2016-09-01 02:59:59                     215.259946
# 2016-09-01 03:59:59                     215.336236
# 2016-09-01 04:59:59                     199.099327
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
# 2016-09-01 01:59:59                         14.987471
# 2016-09-01 02:59:59                         12.884934
# 2016-09-01 03:59:59                         12.006805
# 2016-09-01 04:59:59                         10.682530
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-09-01 00:59:59                         8.080000
# 2016-09-01 01:59:59                         8.080000
# 2016-09-01 02:59:59                         7.786667
# 2016-09-01 03:59:59                         7.640000
# ...

# %%
full = pd.read_csv('/datasets/gold_recovery_full.csv', index_col='date')
full.head()
# Out:
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
# 2016-01-15 01:00:00                     6.029369                     9.968944
# 2016-01-15 02:00:00                     6.055926                    10.213995
# 2016-01-15 03:00:00                     6.047977                     9.977019
# 2016-01-15 04:00:00                     6.148599                    10.142511
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
# 2016-01-15 01:00:00                      5.257781
# 2016-01-15 02:00:00                      5.383759
# 2016-01-15 03:00:00                      4.858634
# 2016-01-15 04:00:00                      4.939416
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2016-01-15 00:00:00                    42.192020              70.541216
# ...

# %% [markdown]
# Посмотрим основную информацию по наборам данных

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16860 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
# final.output.concentrate_ag                           16788 non-null float64
# final.output.concentrate_pb                           16788 non-null float64
# final.output.concentrate_sol                          16490 non-null float64
# final.output.concentrate_au                           16789 non-null float64
# final.output.recovery                                 15339 non-null float64
# final.output.tail_ag                                  16794 non-null float64
# final.output.tail_pb                                  16677 non-null float64
# final.output.tail_sol                                 16715 non-null float64
# final.output.tail_au                                  16794 non-null float64
# primary_cleaner.input.sulfate                         15553 non-null float64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5856 entries, 2016-09-01 00:59:59 to 2017-12-31 23:59:59
# Data columns (total 52 columns):
# primary_cleaner.input.sulfate                 5554 non-null float64
# primary_cleaner.input.depressant              5572 non-null float64
# primary_cleaner.input.feed_size               5856 non-null float64
# primary_cleaner.input.xanthate                5690 non-null float64
# primary_cleaner.state.floatbank8_a_air        5840 non-null float64
# primary_cleaner.state.floatbank8_a_level      5840 non-null float64
# primary_cleaner.state.floatbank8_b_air        5840 non-null float64
# primary_cleaner.state.floatbank8_b_level      5840 non-null float64
# primary_cleaner.state.floatbank8_c_air        5840 non-null float64
# primary_cleaner.state.floatbank8_c_level      5840 non-null float64
# primary_cleaner.state.floatbank8_d_air        5840 non-null float64
# primary_cleaner.state.floatbank8_d_level      5840 non-null float64
# ...

# %%
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22716 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
# final.output.concentrate_ag                           22627 non-null float64
# final.output.concentrate_pb                           22629 non-null float64
# final.output.concentrate_sol                          22331 non-null float64
# final.output.concentrate_au                           22630 non-null float64
# final.output.recovery                                 20753 non-null float64
# final.output.tail_ag                                  22633 non-null float64
# final.output.tail_pb                                  22516 non-null float64
# final.output.tail_sol                                 22445 non-null float64
# final.output.tail_au                                  22635 non-null float64
# primary_cleaner.input.sulfate                         21107 non-null float64
# ...

# %% [markdown]
# Видим, что в наборах данных есть пропуски.
#
# Проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака rougher.output.recovery. Найдем MAE между расчётами и значением признака. Опишем выводы.
#
# Эффективность обогащения будем считать так:
#
# $$
# \text{Recovery} = \frac{C \cdot (F - T) \cdot 100}{F \cdot (C - T)}
# $$
#
# где
# * С - rougher.output.concentrate_au, доля золота в концентрате после флотации
# * F - rougher.input.feed_au, доля золота в сырье до флотации
# * T - rougher.output.tail_au, доля золота в отвальных хвостах после флотации

# %%
def MAE(x, y):
    return (x - y).abs().mean()

def recovery(C, F, T):
    return (C * (F - T) * 100)/(F * (C - T))

params = {
            'C': train['rougher.output.concentrate_au'],
            'F': train['rougher.input.feed_au'],
            'T': train['rougher.output.tail_au']
}

recovery_calculated = recovery(**params)
mae = MAE(recovery_calculated, train['rougher.output.recovery'])
print(f'Средняя абсолютная ошибка MAE: {mae:.2n}')
# Out:
# Средняя абсолютная ошибка MAE: 1.1e-14

# %% [markdown]
# Вывод: видим, что ошибка очень близка к нулю. Будем считать, что коэффициент восстановления расчитан верно.
# ***
# Проанализируем признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?

# %%
l2 = set(train.columns)
l1 = set(test.columns)
l2-l1
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# Видим, что нет параметров, которые относятся к целевым признакам: коэффициентов восстановления после флотации и в финальном продукте. Недоступны параметры состава веществ после всех этапов и в отвале на выходе. Кроме того, отсутствует ряд расчетных параметров этапа флотации. Такая разница обеспечивает отстутсвие утечки целевого признака в тестовые данные.
#
# Для нашей модели будем использовать только те признаки, что есть в тестовом наборе данных.
# ***
# Обратим внимание, что данные отсортированы по дате. И в датах нет пропусков.

# %%
full.index.is_monotonic, train.index.is_monotonic, test.index.is_monotonic
# Out:
# (True, True, True)

# %% [markdown]
# Приведем к корректному типу данных.

# %%
full.index = full.index.astype('datetime64[ns]')
train.index = train.index.astype('datetime64[ns]')
test.index = test.index.astype('datetime64[ns]');

# %% [markdown]
# Проведем предобработку данных. Заполним пропуски.
#
# Будем заполнять предыдущем значением method='ffill', потому что близкие по времени технологические процессы обладают схожими признаками.

# %%
train = train.fillna(method='ffill')
test = test.fillna(method='ffill')
full = full.fillna(method='ffill')

# %% [markdown]
# ## Исследовательский анализ данных <a name="3"></a>

# %% [markdown]
# Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишим выводы.
#
# 1. Концентрация металлов в сырье:
#     * *rougher.input.feed_au (золото)*
#     * *rougher.input.feed_ag (серебро)*
#     * *rougher.input.feed_pb (свинец)*
# ***
# 2. Концентрация металлов в черновом концентрате:
#     * *rougher.output.concentrate_au (золото)*
#     * *rougher.output.concentrate_ag (серебро)*
#     * *rougher.output.concentrate_pb (свинец)*
# ***
# 3. Концентрация металлов в концетрате первой очистки:
#     * *primary_cleaner.output.concentrate_au (золото)*
#     * *primary_cleaner.output.concentrate_ag (серебро)*
#     * *primary_cleaner.output.concentrate_pb (свинец)*
# ***
# 4. Концентрация металлов в финальном продукте:
#     * *final.output.concentrate_au (золото)*
#     * *final.output.concentrate_ag (серебро)*
#     * *final.output.concentrate_pb (свинец)*
#
# Данные будем выводить в виде средних значений концентраций на каждом этапе.

# %%
data = {
        'au': [
               train['rougher.input.feed_au'].mean(), 
               train['rougher.output.concentrate_au'].mean(),
               train['primary_cleaner.output.concentrate_au'].mean(),
               train['final.output.concentrate_au'].mean(),
        ],
        'au_tail':[
               0, 
               train['rougher.output.tail_au'].mean(),
               train['primary_cleaner.output.tail_au'].mean(),
               train['final.output.tail_au'].mean(),
        ],
        'ag': [
               train['rougher.input.feed_ag'].mean(), 
               train['rougher.output.concentrate_ag'].mean(),
               train['primary_cleaner.output.concentrate_ag'].mean(),
               train['final.output.concentrate_ag'].mean(),
        ],
        'ag_tail':[
               0, 
               train['rougher.output.tail_ag'].mean(),
               train['primary_cleaner.output.tail_ag'].mean(),
               train['final.output.tail_ag'].mean(),
        ],
        'pb': [
               train['rougher.input.feed_pb'].mean(), 
               train['rougher.output.concentrate_pb'].mean(),
               train['primary_cleaner.output.concentrate_pb'].mean(),
               train['final.output.concentrate_pb'].mean(),
        ],
        'pb_tail':[
               0, 
               train['rougher.output.tail_pb'].mean(),
               train['primary_cleaner.output.tail_pb'].mean(),
               train['final.output.tail_pb'].mean(),
    ]
}
arrays = [['au', 'au','ag', 'ag','pb', 'pb'],
          ['lvl', 'tail', 'lvl', 'tail', 'lvl', 'tail']]
mi = pd.MultiIndex.from_arrays(arrays)

df = pd.DataFrame(data=data, index=['feed', 'rougher', 'primary_cleaner', 'final'])
df.columns = mi
df.style.format('{:,.1f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_63f0ba6e_3bf5_11eb_bb5f_02420a3919aa" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>au</th>        <th class="col_heading level0 col2" colspan=2>ag</th>        <th class="col_heading level0 col4" colspan=2>pb</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >lvl</th>        <th class="col_heading level1 col1" >tail</th>        <th class="col_heading level1 col2" >lvl</th>        <th class="col_heading level1 col3" >tail</th>        <th class="col_heading level1 col4" >lvl</th>        <th class="col_heading level1 col5" >tail</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_63f0ba6e_3bf5_11eb_bb5f_02420a3919aalevel0_row0" class="row_heading level0 row0" >feed</th>
#                         <td id="T_63f0ba6e_3bf5_11eb_bb5f_02420a3919aarow0_col0" class="data row0 col0" >7.1</td>
# ...

# %% [markdown]
# Выводы: концетрация золота и свинца растет на каждом этапе. Концентрация серебра выросла только после флотации, потом она уменьшается, больше уходит серебра в отвал.
# ***
# Сравним распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
#
# Будем использовать поле rougher.input.feed_size
#
# **Нулевая гипотеза H₀**
#
# *Средний размер гранул сырья на обучающей и тестовой выборке равны между собой*
#
# **Альтернативная гипотеза H₁**
#
# *Средний размер гранул сырья на обучающей и тестовой выборке различаются*
#
# Зададим пороговое значение **alpha 5%**.

# %%
sample_1 = train['rougher.input.feed_size']
sample_2 = test['rougher.input.feed_size']
    
def test_means(sample_1, sample_2):
    results = st.ttest_ind(sample_1, sample_2)
    print('p-значение: ', results.pvalue);

    alpha = .05 # критический уровень статистической значимости
                # если p-value окажется меньше него - отвергнем гипотезу

    if (results.pvalue < alpha):
        print("Отвергаем нулевую гипотезу")
    else:
        print("Не получилось отвергнуть нулевую гипотезу")
        
test_means(sample_1, sample_2)
# Out:
# p-значение:  7.63075072511601e-23
# Отвергаем нулевую гипотезу

# %% [markdown]
# Выводы: видим, что размеры гранул в среднем достаточно сильно различаются, чтобы объяснить это случайностью. Возможно, проблема в выбросах, посмотрим на гистрограммы.

# %%
N = 50
FS = (12, 6)
range = (0, 100)
sample_1.hist(bins=N, figsize = FS)
sample_2.hist(bins=N, figsize = FS);

# %%
sample_1.hist(bins=N, figsize = FS, range=range)
sample_2.hist(bins=N, figsize = FS, range=range);

# %% [markdown]
# Видим, что есть всплеск в тесте на участке 40-45. Похоже в тот период, что пришелся на этот набор, были нетипичные поставки сырья или сбой в добывающем оборудовании, что привело к повышенной коцентрации зерна размера 40-45.
#
# Прорядим такие значения в тесте наполовину и уберем выбросы свыше 100. Не забудем устранить соответствующие записи в полном наборе.

# %%
RS = 42
size_col = 'rougher.input.feed_size'
condition = (test[size_col] > 40) & (test[size_col] < 45)
# удалим 50% от изначальных значений 40-45 в тесте
indexes = test[condition].sample(frac=.50, random_state=RS).index
test = test.drop(indexes)
full = full.drop(indexes)

indexes1 = test[test[size_col] > 100].index
indexes2 = train[train[size_col] > 100].index
test = test.drop(indexes1)
train = train.drop(indexes2)
full = full.drop(indexes1)
full = full.drop(indexes2)

# %% [markdown]
# После того, как выправили распределения, проверим средние.

# %%
sample_1 = train['rougher.input.feed_size']
sample_2 = test['rougher.input.feed_size']
test_means(sample_1, sample_2)
# Out:
# p-значение:  0.0962148470070583
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Теперь данные обучения и теста сравнимы.
# ***
# Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах. Есть ли аномальные значения в суммарном распределении или нет? Если они есть, стоит ли их удалять из обеих выборок? Опишем выводы и удалим аномалии.
#
# Под суммарной концентрацией всех веществ будем понимать сумму на каждом этапе следующих столбцов.
#
# 1. В сырье
#
#     * *rougher.input.feed_au (золото)*
#     * *rougher.input.feed_ag (серебро)*
#     * *rougher.input.feed_pb (свинец)*
# ***
# 2. В черновом концетрате.
#     * *rougher.output.concentrate_au (золото)*
#     * *rougher.output.concentrate_ag (серебро)*
#     * *rougher.output.concentrate_pb (свинец)*
# ***
# 3. В концетрате первой очистки.
#     * *primary_cleaner.output.concentrate_au (золото)*
#     * *primary_cleaner.output.concentrate_ag (серебро)*
#     * *primary_cleaner.output.concentrate_pb (свинец)*
# ***
# 4. В финальном продукте.
#     * *final.output.concentrate_au (золото)*
#     * *final.output.concentrate_ag (серебро)*
#     * *final.output.concentrate_pb (свинец)*
#
# Добавим новые колонки для каждого этапа в обучающем наборе: сумарная концентрация металлов metalls(au+ag+pb).

# %%
def sum_conc(df, stage, elems, name):
    result = [0] * len(df)
    for el in elems:
        result += df[stage+el]
    df[stage + name] = result

    
def add_cols(df):
    metalls = ['au', 'ag', 'pb']
    sum_conc(df, 'rougher.input.feed_', metalls, 'metalls')
    sum_conc(df, 'rougher.output.concentrate_', metalls, 'metalls')
    sum_conc(df, 'primary_cleaner.output.concentrate_', metalls, 'metalls')
    sum_conc(df, 'final.output.concentrate_', metalls, 'metalls')


def plot_dist(df):
    fig, ax = plt.subplots(nrows=1, figsize=(16, 6))

    params = {'bins': 100, 'ax': ax, 'hist': False}

    stages = ['feed', 'rougher', 'primary_cleaner', 'final']

    sns.distplot(df['rougher.input.feed_metalls'],
                 label=stages[0],
                 **params
                )
    sns.distplot(df['rougher.output.concentrate_metalls'],
                 label=stages[1],
                 **params
                )
    sns.distplot(df['primary_cleaner.output.concentrate_metalls'],
                 label=stages[2],
                 **params
                )
    sns.distplot(df['final.output.concentrate_metalls'],
                 label=stages[3],
                 **params
                )

    ax.set_title('Распределение концентрации металлов по этапам')
    ax.set_ylabel('Доля')
    ax.set_xlabel('Концентрация')

    
add_cols(full)
plot_dist(full)

# %% [markdown]
# Выводы: видим, что с каждым следующим этапом концентрация металлов растет. Однако, есть околонулевой всплеск. Посмотрим детальнее на этот участок.

# %%
select = ['rougher.input.feed_au',
          'rougher.input.feed_ag',
          'rougher.input.feed_pb',
          'rougher.input.feed_sol',
          'rougher.input.feed_metalls'
         ]

full[full['final.output.concentrate_metalls'] < 5].head()
# Out:
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-19 03:00:00                          0.0                          0.0
# 2016-01-19 04:00:00                          0.0                          0.0
# 2016-01-19 05:00:00                          0.0                          0.0
# 2016-01-19 06:00:00                          0.0                          0.0
# 2016-01-19 07:00:00                          0.0                          0.0
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-19 03:00:00                           0.0
# 2016-01-19 04:00:00                           0.0
# 2016-01-19 05:00:00                           0.0
# 2016-01-19 06:00:00                           0.0
# 2016-01-19 07:00:00                           0.0
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2016-01-19 03:00:00                          0.0              58.017871
# ...

# %% [markdown]
# Видим, что есть нулевые и околонулевые концентрации металлов на вход. Удалим такие записи из наборов. Похоже, что такие записи появились в результате сбоя считывающих датчиков или их загрязнения.
#
# Нужно будет почистить не только полный набор данных, но и обучающий с тестовым.

# %%
conditional = (full['rougher.input.feed_metalls'] < 5) \
| (full['rougher.output.concentrate_metalls'] < 5) \
| (full['primary_cleaner.output.concentrate_metalls'] < 5) \
| (full['final.output.concentrate_metalls'] < 5)

indexes = full[conditional].index
test_indexes = test[test.index.isin(indexes)].index
train_indexes = train[train.index.isin(indexes)].index

full.drop(indexes, inplace=True)
test.drop(test_indexes, inplace=True)
train.drop(train_indexes, inplace=True)

# %% [markdown]
# Посмотрим на распределения после чистки.

# %%
plot_dist(full)

# %% [markdown]
# Теперь распределения похожи на нормальные с закономерным увеличением на каждом этапе.

# %% [markdown]
# ## Обучение и проверка модели <a name="4"></a>

# %% [markdown]
# Напишем функцию для вычисления итоговой SMAPE.
#
# Будем использовать следующую формулу:
#
# $$
# \text{SMAPE}_{total} = 25\% \cdot \text{SMAPE}_{rougher} + 75\% \cdot \text{SMAPE}_{final}
# $$
#
# где
# * rougher - предсказанный коэффициент восстановления золота после флоатации.
# * final - предсказанный коэффициент золота в финальном продукте.

# %%
def smape(y_true, y_pred):
    error = (y_true - y_pred).abs()
    scale = (y_true.abs() + y_pred.abs()) / 2
    result = (error / scale).mean()
    return result
 

def smape_weighted(y_true, y_pred):
    y_true.reset_index(drop=True, inplace=True)
    y_pred = pd.DataFrame(data=y_pred)
    rougher = smape(y_true.iloc[:, 0], y_pred.iloc[:, 0])
    final = smape(y_true.iloc[:, 1], y_pred.iloc[:, 1])
    return 0.25 * rougher + 0.75 * final

# %% [markdown]
# Обучим разные модели и оценим их качество кросс-валидацией. Выберем лучшую модель.
#
# Попробуем следующие регрессионные модели:
# * линейный регрессор,
# * регрессор дерева решений,
# * регрессор случайного леса.

# %%
target_cols = ['rougher.output.recovery', 'final.output.recovery']
features_train = train[test.columns].reset_index(drop=True)
target_train = train[target_cols].reset_index(drop=True)

# %%
my_scorer =  make_scorer(smape_weighted, greater_is_better=False)

params = {
        'decision_tree': {
            'model': DecisionTreeRegressor(random_state=RS),
            'params': {
                'max_depth': [5, 6],
                'min_samples_split': [2, 3]
            }  
        },
        'random_forest': {
            'model': RandomForestRegressor(random_state=RS, n_jobs=-1),
            'params': {
                'n_estimators': [90, 100],
                'max_depth': [4, 5]
            }
        },
        'LinearRegression': {
            'model': LinearRegression(n_jobs=-1),
            'params': {
                'normalize':[True, False]
            }
        }
    }
    
def hypertune(X_train, y_train, model_params):

    scores = []

    for model_name, mp in model_params.items():
        clf = GridSearchCV(mp['model'], mp['params'], cv=5,
                            scoring=my_scorer, return_train_score=False)
        clf.fit(X_train, y_train)
        scores.append({
            'model': model_name,
            'best_score': f'{clf.best_score_:.2f}',
            'best_params': clf.best_params_
        })

    scores = pd.DataFrame(scores, columns=['model','best_score', 'best_params'])
    return scores.sort_values(by='best_score', ascending=False)

result = hypertune(features_train, target_train, params)
result
# Out:
#               model best_score                               best_params
# 0     decision_tree      -0.10  {'max_depth': 5, 'min_samples_split': 2}
# 2  LinearRegression      -0.10                      {'normalize': False}
# 1     random_forest      -0.09      {'max_depth': 4, 'n_estimators': 90}

# %% [markdown]
# Показатель со знаком минус, потому что метрика является мерой ошибки и чем меньше, тем лучше. Это особенность вывода. Лучшей моделью оказался линейный регрессор без нормализации (значение по умолчанию). Проверим лучшую модель на тестовой выборке.

# %%
model = LinearRegression(n_jobs=-1)
model.fit(features_train, target_train)
y_pred = model.predict(test)
y_true = full.loc[test.index, target_cols]
score = smape_weighted(y_true, y_pred)
f'Итоговый SMAPE: {score:.2%}'
# Out:
# 'Итоговый SMAPE: 7.56%'

# %% [markdown]
# Выводы: метрика итоговый smape достиг значения 7.5. Относительная ошибка в предсказаниях была небольшой и модель может быть использована для производственных целей.
# ***
# Покажем сравнение относительно константной модели. Посчитаем медианные значения по восстановлению золота после флотации, в финальном продукте и посчитаем итоговый SMAPE.

# %%
y_pred = np.array([y_true.median()]*len(test))
score = smape_weighted(y_true, y_pred)
f'Итоговый SMAPE: {score:.2%}'
# Out:
# 'Итоговый SMAPE: 7.13%'

# %% [markdown]
# Видим, что предсказания константной модели соизмеримы с показателем ошибки в обученной модели. Скорее всего нам неповезло с данными, медианы очень уж точно предсказывают значения. Вероятно, нам потребуется собрать дополнительные объемы данных для обучения, чтобы посмотреть не получится ли обучить еще более точно модель и сравнить их с медианными значениями. А пока будем использовать эту модель.

# %% [markdown]
# ## Общий вывод <a name="5"></a>

# %% [markdown]
# Мы загрузили три набора данных: обучающий, тестовый и полный. Отметки времени уникальные и монотонно возрастают, поэтому могут быть использованы для связи сведений по замерам. Обнаружили пропуски и заполнили предыдущими значениями, поскольку параметры близких по времени замеров близки по значению.
#
# Для того, чтобы тестовые и обучающие данные были соизмеримы друг с другом по среднему размеру гранул, уменьшили количество замеров с размеров зерна 40-45 вдвое в тестовых данных. Кроме того, убрали записи с гранулами больше 100.
#
# При изучении сумарной концентрации веществ на каждом этапе обнаружи концентрации близкие к нулю, которые давали всплески на гистограмме и не соответствовали нормальному распределению. Устранили такие записи.
#
# Изучили разные модели и их гиперпараметры по метрике итоговый SMAPE. Лучшей моделью оказался линейный регрессор со показателем относительной ошибки 7.5. Такая ошибка невелика и модель может быть использована для производственных целей. Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
